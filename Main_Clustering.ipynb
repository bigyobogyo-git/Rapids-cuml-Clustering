# %%
# !pip install ipynb

# %%
import torch
import gc

# %%
torch.cuda.empty_cache()
gc.collect()
# Out:
# 20

# %%
from ipynb.fs.full.KMEANS_to_import import *
# Out:
# /home/xy/Desktop/ml/KMEANS_to_import.ipynb:19: FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
#   "from cuml import KMeans\n",
# Execution time: 6.544557809829712 seconds
# Execution time: 0.08121132850646973 seconds
# /home/xy/Desktop/ml/KMEANS_to_import.ipynb:93: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   "      <th>2</th>\n",
# Execution time: 37.778077602386475 seconds
# Execution time: 6.425809383392334 seconds
# Execution time: 0.06386566162109375 seconds
# /home/xy/Desktop/ml/rapid-cudf-minimal/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# Execution time: 37.047133445739746 seconds
# KMeans seaborn is finished. Run clust_seaborn.plotting !

# %%
from ipynb.fs.full.HDBSCAN_to_import import *
# Out:
# /home/xy/Desktop/ml/HDBSCAN_to_import.ipynb:18: FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
#   "import seaborn as sns\n",
# Execution time: 1018.9921221733093 seconds
# Execution time: 0.08073115348815918 seconds
# /home/xy/Desktop/ml/HDBSCAN_to_import.ipynb:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   "      <td>2006-12-16 17:27:00</td>\n",
# Execution time: 38.0288724899292 seconds
# Execution time: 1015.2750518321991 seconds
# Execution time: 0.06660628318786621 seconds
# Execution time: 23.05111861228943 seconds

# %%
from ipynb.fs.full.Spectral_Clustering_to_import import *
# Out:
# /home/xy/Desktop/ml/Spectral_Clustering_to_import.ipynb:18: FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
#   "import seaborn as sns\n",
# Execution time: 652.5817406177521 seconds
# Execution time: 0.07645106315612793 seconds
# /home/xy/Desktop/ml/Spectral_Clustering_to_import.ipynb:92: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   "      <th>2</th>\n",
# Execution time: 38.43197965621948 seconds
# Sectral Clustering matplotlib is finished. Run clust_matplotlib.plotting !
# Execution time: 650.7105946540833 seconds
# Execution time: 0.06009936332702637 seconds
# Execution time: 23.050785779953003 seconds
# Sectral Clustering seaborn is finished. Run clust_seaborn.plotting !

# %%
from ipynb.fs.full.Agglomerative_Clustering_to_import import *
# Out:
# /home/xy/Desktop/ml/Agglomerative_Clustering_to_import.ipynb:18: FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
#   "import seaborn as sns\n",
# Execution time: 6528.373120069504 seconds
# Execution time: 0.07034993171691895 seconds
# /home/xy/Desktop/ml/Agglomerative_Clustering_to_import.ipynb:87: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   "      <td>0.0</td>\n",
# Execution time: 38.0520555973053 seconds
# Execution time: 6538.704945087433 seconds
# Execution time: 0.0881190299987793 seconds
# Execution time: 23.2051420211792 seconds
